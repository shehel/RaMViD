# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
from IPython.display import HTML

# %%
all_images = np.load('/tmp/openai-2022-11-18-20-22-14-612490/true.npz')    
all_images = all_images['arr_0']

imgs = []
fig, ax = plt.subplots(figsize=(8, 8))
for img in (all_images[0, 0,:,:,:]):
    img = ax.imshow(img, animated=True)
    imgs.append([img])

ani = animation.ArtistAnimation(fig, imgs, interval=1000, blit=True, repeat_delay=2000)
HTML(ani.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="800.1">
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
all_images.shape
# Out:
# (1, 4, 12, 128, 128)

# %%
all_images = np.load('/tmp/openai-2022-11-18-20-22-14-612490/1x12x128x128x4.npz')    
all_images = all_images['arr_0']

imgs = []
fig, ax = plt.subplots(figsize=(8, 8))
for img in (all_images[0, :,:,:,0]):
    img = ax.imshow(img, animated=True)
    imgs.append([img])

ani = animation.ArtistAnimation(fig, imgs, interval=1000, blit=True, repeat_delay=2000)
HTML(ani.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="800.1">
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...
